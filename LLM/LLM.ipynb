# %%
pip install einops
pip install sentence_transformers

# %%
from text_embedding import text_embedding
import torch

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

filename = 'text_embedding_medium'
text_embedding = text_embedding(32, 0.67, filename, device)
#print(text_embedding.embedding)
loaded_tensor = torch.load(filename + '.pth', weights_only=True)

print(loaded_tensor)

#filename = 'text_embedding_large'
#text_embedding = text_embedding(32, 1, filename, device)
#print(text_embedding.embedding)
#loaded_tensor = torch.load(filename + '.pth', weights_only=True)
# Out:
# Using device: cpu
# <All keys matched successfully>
# 0.0008551119662230773
# 0.0017102239324461547
# 0.002565335898669232
# 0.0034204478648923093
# 0.0042755598311153865
# 0.005130671797338464
# 0.005985783763561541
# 0.006840895729784619
# 0.007696007696007696
# 0.008551119662230773
# 0.00940623162845385
# 0.010261343594676928
# 0.011116455560900006
# 0.011971567527123082
# 0.01282667949334616
# 0.013681791459569237
# 0.014536903425792315
# 0.015392015392015393
# 0.01624712735823847
# 0.017102239324461546
# 0.017957351290684626
# 0.0188124632569077
# 0.019667575223130777
# 0.020522687189353857
# 0.021377799155576933
# 0.022232911121800012
# 0.023088023088023088
# 0.023943135054246164
# 0.024798247020469243
# 0.02565335898669232
# 0.0265084709529154
# 0.027363582919138475
# 0.02821869488536155
# 0.02907380685158463
# 0.029928918817807706
# 0.030784030784030785
# 0.03163914275025386
# 0.03249425471647694
# 0.03334936668270001
# 0.03420447864892309
# 0.03505959061514617
# ...

# %%
filename = 'text_embedding_large'
text_embedding = text_embedding(32, 1, filename, device)
#print(text_embedding.embedding)
loaded_tensor = torch.load(filename + '.pth', weights_only=True)

print(loaded_tensor)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 2
#       1 filename = 'text_embedding_large'
# ----> 2 text_embedding = text_embedding(32, 1, filename, device)
#       3 #print(text_embedding.embedding)
#       4 loaded_tensor = torch.load(filename + '.pth', weights_only=True)
#
# TypeError: 'text_embedding' object is not callable
